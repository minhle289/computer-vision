# %% [markdown]
# # Tests

# %% [markdown]
# ## Display results from filtering images (RGB)

# %%
from IPython.display import Image, display

list0 = ['results/identity_image.jpg','results/blur_image.jpg','results/large_blur_image.jpg',
         'results/sobel_image.jpg', 'results/laplacian_image.jpg', 'results/high_pass_image.jpg']

for image in list0:
    display(Image(filename=image))

# %% [markdown]
# # Display results from filtering image (Gray scale)

# %%
list1 = ['results/identity_image_gray.jpg','results/blur_image_gray.jpg','results/large_blur_image_gray.jpg',
         'results/sobel_image_gray.jpg', 'results/laplacian_image_gray.jpg', 'results/high_pass_image_gray.jpg']

for image in list1:
    display(Image(filename=image))

# %% [markdown]
# ## Display cat-dog images, high/low frequencies and hybrid image

# %%
list2 = ['results/low_frequencies_catdog.jpg','results/high_frequencies_catdog.jpg','results/hybrid_image_catdog.jpg',
         'results/hybrid_image_scales_catdog.jpg']

for image in list2:
    display(Image(filename=image))

# %% [markdown]
# ## Display other pic combinations

# %%
list3 = ['results/hybrid_image_sea.jpg','results/hybrid_image_sky.jpg',
         'results/hybrid_image_face.jpg','results/hybrid_image_bike.jpg']

for image in list3:
    display(Image(filename=image))
